# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# read Airbnb_Open_Data.csv file
test_df = pd.read_csv('Airbnb_Open_Data.csv')

# %%
test_df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host_name neighbourhood_group neighbourhood      lat  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington  40.6475
# 1               verified     Jenna           Manhattan       Midtown  40.7536
# 2                    NaN     Elise           Manhattan        Harlem  40.8090
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill  40.6851
# 4               verified    Lyndon           Manhattan   East Harlem  40.7985
#
# ...

# %%
test_df['total_price'] = test_df['total_price'].astype(int)

# %%
print(test_df.columns)
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long', 'country',
#        'country_code', 'instant_bookable', 'cancellation_policy', 'room_type',
#        'Construction_year', 'price', 'service_fee', 'total_price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'review_rate_number',
#        'calculated_host_listings_count', 'availability_365', 'house_rules'],
#       dtype='object')

# %%
test_df.count()
# Out:
# id             102599
# host id        102599
# room_type      102599
# total_price    102599
# dtype: int64

# %%
# drop na's if 3 or more columns have blanks
test_df = test_df.dropna(thresh=3)

# %%
# drop duplicates
test_df = test_df.drop_duplicates()

# %%
test_df.count()
# Out:
# id             102058
# host id        102058
# room_type      102058
# total_price    102058
# dtype: int64

# %%
# Calculate the average total price for each neighborhood
neighbourhood_avg_price = test_df.groupby('neighbourhood')['total_price'].mean()

# Create a bar chart of the average total price for each neighborhood
fig, ax = plt.subplots()
ax.bar(neighbourhood_avg_price.index, neighbourhood_avg_price.values)

# Set plot title and axis labels
ax.set_title("Average Total Price by neighbourhood")
ax.set_xlabel("neighbourhood")
ax.set_ylabel("Average Total Price")

# Rotate x-axis tick labels for better visibility
plt.xticks(rotation=90)

# Display the plot
plt.show()
