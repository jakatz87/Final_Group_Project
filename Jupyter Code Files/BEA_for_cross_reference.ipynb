# %%
import pandas as pd

# %%
#Read the file from GitHub raw
BEA_cross_df=pd.read_csv('https://raw.githubusercontent.com/jakatz87/Final_Group_Project/main/outdoor_rec_BEA_data_pull.csv')
BEA_cross_df.head(10)
# Out:
#    GeoName  LineCode                         Description     2012     2013  \
# 0  Alabama         1           Total Outdoor Recreation   3807374  3886358
# 1  Alabama         2      Total Core Outdoor Recreation   2065590  2139978
# 2  Alabama         3    Conventional Outdoor Recreation   1422123  1474936
# 3  Alabama         4                          Bicycling     12660    13251
# 4  Alabama         5                    Boating/Fishing    215849   217589
# 5  Alabama         6                  Canoeing/Kayaking      6983     5656
# 6  Alabama         7         Fishing (excludes Boating)     51103    52601
# 7  Alabama         8                            Sailing     16265    17376
# 8  Alabama         9                      Other Boating    141498   141957
# 9  Alabama        10       Climbing/Hiking/Tent Camping     39177    39861
#
#       2014     2015     2016     2017     2018     2019     2020     2021
# ...

# %%
#Keep only the Gubmint Expenses as data
BEA_cross_df=BEA_cross_df[BEA_cross_df['Description']=='   Government Expenditures ']
BEA_cross_df.head(10)
# Out:
#                   GeoName  LineCode                  Description     2012  \
# 43                Alabama        44     Government Expenditures    197210
# 89                 Alaska        44     Government Expenditures     76803
# 135               Arizona        44     Government Expenditures    386583
# 181              Arkansas        44     Government Expenditures    145929
# 227            California        44     Government Expenditures   2779588
# 273              Colorado        44     Government Expenditures    568335
# 319           Connecticut        44     Government Expenditures    139311
# 365              Delaware        44     Government Expenditures     31547
# 411  District of Columbia        44     Government Expenditures    211661
# 457               Florida        44     Government Expenditures   1233208
#
#         2013     2014     2015     2016     2017     2018     2019     2020  \
# 43    209690   220662   229060   249586   261420   270939   269117   282616
# ...

# %%
#Change the states to the abbreviations
state_dict = {'Alabama': 'AL', 'Alaska': 'AK', 'Arizona': 'AZ', 'Arkansas': 'AR', 'California': 'CA', 
              'Colorado': 'CO', 'Connecticut': 'CT', 'Delaware': 'DE', 'Florida': 'FL', 'Georgia': 'GA',
              'Hawaii': 'HI', 'Idaho': 'ID', 'Illinois': 'IL', 'Indiana': 'IN', 'Iowa': 'IA', 
              'Kansas': 'KS', 'Kentucky': 'KY', 'Louisiana': 'LA', 'Maine': 'ME', 'Maryland': 'MD', 
              'Massachusetts': 'MA', 'Michigan': 'MI', 'Minnesota': 'MN', 'Mississippi': 'MS', 
              'Missouri': 'MO', 'Montana': 'MT', 'Nebraska': 'NE', 'Nevada': 'NV', 'New Hampshire': 'NH', 
              'New Jersey': 'NJ', 'New Mexico': 'NM', 'New York': 'NY', 'North Carolina': 'NC', 
              'North Dakota': 'ND', 'Ohio': 'OH', 'Oklahoma': 'OK', 'Oregon': 'OR', 'Pennsylvania': 'PA', 
              'Rhode Island': 'RI', 'South Carolina': 'SC', 'South Dakota': 'SD', 'Tennessee': 'TN', 
              'Texas': 'TX', 'Utah': 'UT', 'Vermont': 'VT', 'Virginia': 'VA', 'Washington': 'WA', 
              'West Virginia': 'WV', 'Wisconsin': 'WI', 'Wyoming': 'WY', 'District of Columbia': 'DC'}
BEA_cross_df['State']=BEA_cross_df['GeoName'].map(state_dict)
BEA_cross_df=BEA_cross_df.drop(['GeoName'], axis=1)
BEA_cross_df.head(10)
# Out:
#      LineCode                  Description     2012     2013     2014  \
# 43         44     Government Expenditures    197210   209690   220662
# 89         44     Government Expenditures     76803    84429    90094
# 135        44     Government Expenditures    386583   426882   445864
# 181        44     Government Expenditures    145929   156430   161631
# 227        44     Government Expenditures   2779588  2790242  2817304
# 273        44     Government Expenditures    568335   586706   607709
# 319        44     Government Expenditures    139311   147599   154708
# 365        44     Government Expenditures     31547    34528    36660
# 411        44     Government Expenditures    211661   244185   245981
# 457        44     Government Expenditures   1233208  1333858  1394757
#
#         2015     2016     2017     2018     2019     2020     2021 State
# 43    229060   249586   261420   270939   269117   282616   310347    AL
# ...

# %%
#Reorder the columns
BEA_cross_df=BEA_cross_df[['LineCode', 'State', 'Description', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']]
BEA_cross_df.head(10)
# Out:
#      LineCode State                  Description     2012     2013     2014  \
# 43         44    AL     Government Expenditures    197210   209690   220662
# 89         44    AK     Government Expenditures     76803    84429    90094
# 135        44    AZ     Government Expenditures    386583   426882   445864
# 181        44    AR     Government Expenditures    145929   156430   161631
# 227        44    CA     Government Expenditures   2779588  2790242  2817304
# 273        44    CO     Government Expenditures    568335   586706   607709
# 319        44    CT     Government Expenditures    139311   147599   154708
# 365        44    DE     Government Expenditures     31547    34528    36660
# 411        44    DC     Government Expenditures    211661   244185   245981
# 457        44    FL     Government Expenditures   1233208  1333858  1394757
#
#         2015     2016     2017     2018     2019     2020     2021
# ...

# %%
# Create the output file (CSV).
output_data_file = "BEA_data_for_cross_reference.csv"
# Export the data into a CSV.
BEA_cross_df.to_csv(output_data_file)
